# %%
import pandas as pd

# Create a sample dataset
data = {
    'track_name': ['Song1', 'Song2', 'Song3', 'Song4', 'Song5', 'Song6', 'Song7', 'Song8', 'Song9', 'Song10'],
    'artist': ['Artist1', 'Artist2', 'Artist3', 'Artist4', 'Artist5', 'Artist6', 'Artist7', 'Artist8', 'Artist9', 'Artist10'],
    'genre': ['pop', 'rock', 'hip hop', 'pop', 'electronic', 'rock', 'pop', 'hip hop', 'electronic', 'rock'],
    'danceability': [0.72, 0.65, 0.85, 0.70, 0.75, 0.68, 0.82, 0.78, 0.71, 0.69],
    'energy': [0.65, 0.80, 0.72, 0.68, 0.85, 0.75, 0.70, 0.82, 0.76, 0.79],
    'loudness': [-6.5, -4.2, -5.8, -7.1, -3.9, -5.2, -6.8, -4.5, -5.9, -4.8],
    'speechiness': [0.05, 0.08, 0.12, 0.04, 0.06, 0.09, 0.07, 0.15, 0.05, 0.08],
    'acousticness': [0.25, 0.15, 0.08, 0.30, 0.12, 0.18, 0.22, 0.10, 0.28, 0.16],
    'instrumentalness': [0.02, 0.01, 0.00, 0.03, 0.15, 0.02, 0.01, 0.00, 0.08, 0.02],
    'liveness': [0.08, 0.12, 0.15, 0.09, 0.11, 0.14, 0.10, 0.16, 0.09, 0.13],
    'valence': [0.65, 0.58, 0.72, 0.68, 0.70, 0.62, 0.75, 0.69, 0.64, 0.60],
    'tempo': [120, 135, 95, 118, 128, 122, 108, 98, 125, 132],
    'popularity': [85, 72, 90, 78, 82, 70, 88, 75, 80, 68]
}

df = pd.DataFrame(data)

# Save to CSV
df.to_csv('spotify_sample_dataset.csv', index=False)

# Display first few rows
print(df.head())

# Display basic statistics
print("\nDataset Info:")
print(df.info())

print("\nBasic Statistics:")
print(df.describe())
# Out:
#   track_name   artist       genre  danceability  energy  loudness  \
# 0      Song1  Artist1         pop          0.72    0.65      -6.5
# 1      Song2  Artist2        rock          0.65    0.80      -4.2
# 2      Song3  Artist3     hip hop          0.85    0.72      -5.8
# 3      Song4  Artist4         pop          0.70    0.68      -7.1
# 4      Song5  Artist5  electronic          0.75    0.85      -3.9
#
#    speechiness  acousticness  instrumentalness  liveness  valence  tempo  \
# 0         0.05          0.25              0.02      0.08     0.65    120
# 1         0.08          0.15              0.01      0.12     0.58    135
# 2         0.12          0.08              0.00      0.15     0.72     95
# 3         0.04          0.30              0.03      0.09     0.68    118
# 4         0.06          0.12              0.15      0.11     0.70    128
#
#    popularity
# 0          85
# 1          72
# 2          90
# 3          78
# 4          82
#
# Dataset Info:
# ...
